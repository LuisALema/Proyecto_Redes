# %% [markdown]
# # Documentacion sobre Proyecto de interconexion de Redes “Carnaval Conectado Brasil – Infraestructura Tecnológica para un Evento Masivo”

# %% [markdown]
# ## 1. Diseño de Red y Vlsm

# %% [markdown]
# Aqui solo poner algo Simplificado cris en el ipynb que dice Vlsm y Diseño ahi le pones todo explicado bien y con tablas para despues convertirlo en pdf con latex

# %% [markdown]
# ## 2. Redes LAN

# %% [markdown]
# ## 3. Redes Wan
